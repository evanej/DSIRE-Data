# %%
# This file contains the json version of the DSIRE data
# The three files are first uploaded into jupyter notebook,
#     then compiled into one file, and then filtered for each of
#     the key terms in their own cell
# The filter results are listed in comments after each cell

# Note that the files are originally pulled from my desktop, so for
#     someone else to use this code, those lines need to be updated
# Also note that to filter for a word, it must be changed in the
#     "filterfunction" function under "searchterm"

# %%
import numpy as np
import pandas as pd
import json
from functools import reduce
from operator import itemgetter

# %%
data1 = ""
data2 = ""
data3 = ""
#data1 will be DSIRE data from Jan. 1, 2010 - Dec. 31, 2013
#data2 will be DSIRE data Jan. 1, 2014 - Dec. 31, 2016
#data3 will be DSIRE data Jan. 1, 2017 - July 1, 2020

# %%
with open('/Users/Jax/Desktop/Research with Evan/DSIRE_json_files/dsire_2010-2013.json', 'r') as read_file:
    data1 = json.load(read_file)

# %%
data1

# %%
with open('/Users/Jax/Desktop/Research with Evan/DSIRE_json_files/dsire_2014-2016.json', 'r') as read_file:
    data2 = json.load(read_file)

# %%
data2

# %%
with open('/Users/Jax/Desktop/Research with Evan/DSIRE_json_files/dsire_2017-2020.json', 'r') as read_file:
    data3= json.load(read_file)

# %%
data3

# %%
datalist1 = data1["data"]
datalist2 = data2["data"]
datalist3 = data3["data"]

#Includes just the data from each dataset, not the metadata listed at the end of each file

# %%
#Tests to figure out how to best combine the data:

# %%
# test_data_1 = []
# test_data_1.append(datalist1[0])
# test_data_1.append(datalist1[1])
# test_data_2 = []
# test_data_2.append(datalist2[1])
# test_data_2.append(datalist2[5])
# print("test data 1:", test_data_1, "\n", "\n", "Test Data 2:", test_data_2)

# %%
# merge_test = []
# merge_test = test_data_1 + test_data_2
# merge_test

# %%
#Combining the data:

# %%
alldata = datalist1 + datalist2
alldata = alldata + datalist3
alldata
# Out:
# [{'ProgramId': 59,
#   'Name': 'Voluntary Renewable Resources Grants',
#   'Code': 'ME03F',
#   'LastUpdate': '12/05/2012',
#   'Published': False},
#  {'ProgramId': 72,
#   'Name': 'Montana Electric Coops - Net Metering',
#   'Code': 'MT10R',
#   'LastUpdate': '12/07/2012',
#   'Published': False},
#  {'ProgramId': 79,
#   'Name': 'Energy Conversion Facilities Property Tax Exemption',
#   'Code': 'OH02F',
#   'LastUpdate': '03/01/2010',
#   'Published': False},
#  {'ProgramId': 86,
#   'Name': 'GMP - Biomass Grants',
#   'Code': 'VT06F',
#   'LastUpdate': '12/04/2012',
#   'Published': False},
#  {'ProgramId': 89,
#   'Name': 'Klickitat PUD - Solar PV Rebate',
#   'Code': 'WA24F',
#   'LastUpdate': '01/10/2012',
#   'Published': False},
#  {'ProgramId': 91,
#   'Name': 'Klickitat PUD - Solar PV Loan Program',
#   'Code': 'WA25F',
#   'LastUpdate': '01/10/2012',
#   'Published': False},
#  {'ProgramId': 100,
#   'Name': 'Technology and Demonstration Grants',
#   'Code': 'DE02F',
#   'LastUpdate': '08/18/2011',
#   'Published': False},
#  {'ProgramId': 101,
#   'Name': 'Research and Development Grants',
#   'Code': 'DE04F',
#   'LastUpdate': '08/18/2011',
#   'Published': False},
#  {'ProgramId': 111,
#   'Name': 'Energy Efficiency Grants',
#   'Code': 'MI14F',
#   'LastUpdate': '01/26/2012',
#   'Published': False},
#  {'ProgramId': 153,
#   'Name': 'Green Building Tax Credit Program (Personal)',
#   'Code': 'NY15F',
#   'LastUpdate': '06/09/2011',
#   'Published': False},
#  {'ProgramId': 167,
#   'Name': 'Business Energy Tax Credit',
#   'Code': 'OR03F',
#   'LastUpdate': '02/03/2012',
#   'Published': False},
#  {'ProgramId': 171,
#   'Name': 'Renewable Energy Systems Exemption',
#   'Code': 'SD01F',
#   'LastUpdate': '07/06/2010',
#   'Published': False},
#  {'ProgramId': 174,
#   'Name': 'Green Building Tax Credit Program (Corporate)',
#   'Code': 'NY05F',
#   'LastUpdate': '06/09/2011',
#   'Published': False},
#  {'ProgramId': 177,
#   'Name': 'Mass Energy Consumers Alliance - Renewable Energy Certificate Incentive',
#   'Code': 'MA10F',
#   'LastUpdate': '07/12/2010',
#   'Published': False},
#  {'ProgramId': 194,
#   'Name': 'Residential Renewable Energy Tax Credit (Personal)',
#   'Code': 'RI07F',
#   'LastUpdate': '03/02/2012',
#   'Published': False},
#  {'ProgramId': 199,
#   'Name': 'Biomass Energy Program',
#   'Code': 'AL02F',
#   'LastUpdate': '11/21/2013',
#   'Published': False},
#  {'ProgramId': 202,
#   'Name': 'City of San Diego - Green Power Purchasing',
#   'Code': 'CA41R',
#   'LastUpdate': '12/14/2011',
#   'Published': False},
#  {'ProgramId': 216,
#   'Name': 'Small Business Energy Loan Program',
#   'Code': 'TN01F',
#   'LastUpdate': '09/01/2010',
#   'Published': False},
#  {'ProgramId': 221,
#   'Name': 'Clark County - Green Power Purchasing',
#   'Code': 'WA10R',
#   'LastUpdate': '09/13/2011',
#   'Published': False},
#  {'ProgramId': 228,
#   'Name': 'Alternative Power & Energy Grant Program',
#   'Code': 'IN02F',
#   'LastUpdate': '08/04/2010',
#   'Published': False},
#  {'ProgramId': 252,
#   'Name': 'Iowa Energy Center - Grants for Energy Efficiency and Renewable Energy Research',
#   'Code': 'IA07F',
#   'LastUpdate': '07/01/2010',
#   'Published': False},
#  {'ProgramId': 263,
#   'Name': 'City of San Francisco - Renewable Energy Purchasing',
#   'Code': 'CA43R',
#   'LastUpdate': '12/14/2011',
#   'Published': False},
#  {'ProgramId': 272,
#   'Name': 'City of Scottsdale - Green Power Purchasing',
#   'Code': 'AZ15R',
#   'LastUpdate': '07/20/2012',
#   'Published': False},
#  {'ProgramId': 332,
#   'Name': 'MTC - Matching Grants for Communities',
#   'Code': 'MA21F',
#   'LastUpdate': '03/11/2010',
#   'Published': False},
#  {'ProgramId': 338,
#   'Name': 'CCEF - Project 150 Initiative',
#   'Code': 'CT12F',
#   'LastUpdate': '01/06/2010',
#   'Published': False},
#  {'ProgramId': 350,
#   'Name': 'Renewable Energy Equipment Sales Tax Refund',
#   'Code': 'ID08F',
#   'LastUpdate': '09/02/2011',
#   'Published': False},
#  {'ProgramId': 351,
#   'Name': 'Pennsylvania Energy Development Authority (PEDA) - Grants',
#   'Code': 'PA16F',
#   'LastUpdate': '06/11/2012',
#   'Published': False},
#  {'ProgramId': 368,
#   'Name': 'Ferry County PUD #1 - Off-Grid Solar PV Financial Assistance',
#   'Code': 'WA26F',
#   'LastUpdate': '08/22/2012',
#   'Published': False},
#  {'ProgramId': 369,
#   'Name': 'Suffolk County - Green Power Purchasing Policy',
#   'Code': 'NY06R',
#   'LastUpdate': '08/24/2011',
#   'Published': False},
#  {'ProgramId': 370,
#   'Name': 'Montgomery County - Clean Energy Rewards Program',
#   'Code': 'MD15F',
#   'LastUpdate': '10/01/2010',
#   'Published': False},
#  {'ProgramId': 408,
#   'Name': 'City of San Jose - Municipal Green Building Program',
#   'Code': 'CA08R',
#   'LastUpdate': '06/21/2012',
#   'Published': False},
#  {'ProgramId': 414,
#   'Name': 'Fuel Mix and Emissions Disclosure',
#   'Code': 'AZ12R',
#   'LastUpdate': '02/02/2011',
#   'Published': False},
#  {'ProgramId': 419,
#   'Name': 'Portland - Green Power Purchasing & Generation',
#   'Code': 'OR17R',
#   'LastUpdate': '03/25/2011',
#   'Published': False},
#  {'ProgramId': 420,
#   'Name': 'City of Madison - Green Power Purchasing',
#   'Code': 'WI10R',
#   'LastUpdate': '07/30/2012',
#   'Published': False},
#  {'ProgramId': 435,
#   'Name': 'Orcas Power & Light - Photovoltaic Rebate',
#   'Code': 'WA06F',
#   'LastUpdate': '12/16/2011',
#   'Published': False},
#  {'ProgramId': 470,
#   'Name': 'Residential Loan Fund',
#   'Code': 'NY06F',
#   'LastUpdate': '11/20/2012',
#   'Published': False},
#  {'ProgramId': 475,
#   'Name': "People's Power & Light - Renewable Energy Certificate Incentive",
#   'Code': 'RI08F',
#   'LastUpdate': '07/12/2010',
#   'Published': False},
#  {'ProgramId': 508,
#   'Name': 'EPUD - Solar Water Heater Rebate',
#   'Code': 'OR05F',
#   'LastUpdate': '02/01/2013',
#   'Published': False},
#  {'ProgramId': 509,
#   'Name': 'EWEB - Residential Solar Water Heating Rebate',
#   'Code': 'OR06F',
#   'LastUpdate': '01/14/2013',
#   'Published': False},
#  {'ProgramId': 515,
#   'Name': 'EPUD - Solar Water Heater Loan',
#   'Code': 'OR07F',
#   'LastUpdate': '02/01/2013',
#   'Published': False},
#  {'ProgramId': 548,
#   'Name': 'Emerging Renewables Program',
#   'Code': 'CA30F',
#   'LastUpdate': '03/05/2013',
#   'Published': False},
#  {'ProgramId': 581,
#   'Name': 'Renewable Power Procurement Policy',
#   'Code': 'NY08R',
#   'LastUpdate': '08/31/2012',
#   'Published': False},
#  {'ProgramId': 600,
#   'Name': 'Pennsylvania Energy Harvest Grant Program',
#   'Code': 'PA06F',
#   'LastUpdate': '04/09/2010',
#   'Published': False},
#  {'ProgramId': 635,
#   'Name': 'Income Tax Credit for Green Buildings (Corporate)',
#   'Code': 'MD09F',
#   'LastUpdate': '01/02/2012',
#   'Published': False},
#  {'ProgramId': 636,
#   'Name': 'Income Tax Credit for Green Buildings (Personal)',
#   'Code': 'MD10F',
#   'LastUpdate': '01/02/2012',
#   'Published': False},
#  {'ProgramId': 649,
#   'Name': 'Solar-Electric (PV) Rebate Program',
#   'Code': 'MN09F',
#   'LastUpdate': '10/05/2010',
#   'Published': False},
#  {'ProgramId': 668,
#   'Name': 'Illinois - Green Power Purchasing',
#   'Code': 'IL06R',
#   'LastUpdate': '01/06/2011',
#   'Published': False},
#  {'ProgramId': 671,
#   'Name': 'Pacific County PUD - Solar Water Heater Rebate',
#   'Code': 'WA10F',
#   'LastUpdate': '08/23/2012',
#   'Published': False},
#  {'ProgramId': 683,
#   'Name': 'Energy Improvement Loan Program (EILP)',
#   'Code': 'NC01F',
#   'LastUpdate': '04/16/2012',
#   'Published': False},
#  {'ProgramId': 692,
#   'Name': 'Franklin County PUD - Solar Energy System Rebate',
#   'Code': 'WA12F',
#   'LastUpdate': '04/24/2011',
#   'Published': False},
#  {'ProgramId': 729,
#   'Name': 'Renewable Energy Production Incentive (REPI)',
#   'Code': 'US33F',
#   'LastUpdate': '02/02/2012',
#   'Published': False},
#  {'ProgramId': 755,
#   'Name': 'High Technology Business Investment Tax Credit',
#   'Code': 'HI12F',
#   'LastUpdate': '06/20/2011',
#   'Published': False},
#  {'ProgramId': 774,
#   'Name': 'Small Commercial Wind Energy Property Tax Assessment',
#   'Code': 'SD05F',
#   'LastUpdate': '06/15/2011',
#   'Published': False},
#  {'ProgramId': 813,
#   'Name': 'Clallam County PUD - Residential Solar Rebate Program',
#   'Code': 'WA21F',
#   'LastUpdate': '03/01/2011',
#   'Published': False},
#  {'ProgramId': 834,
#   'Name': 'Salt Lake City - Green Power Purchasing',
#   'Code': 'UT06R',
#   'LastUpdate': '10/02/2012',
#   'Published': False},
#  {'ProgramId': 854,
#   'Name': 'Franklin County PUD - Solar Energy System Loan',
#   'Code': 'WA13F',
#   'LastUpdate': '05/28/2010',
#   'Published': False},
#  {'ProgramId': 868,
#   'Name': 'Marin County - Solar Rebate Program',
#   'Code': 'CA01F',
#   'LastUpdate': '03/05/2013',
#   'Published': False},
#  {'ProgramId': 869,
#   'Name': 'Marin County - Green Building Incentive Program',
#   'Code': 'CA08F',
#   'LastUpdate': '08/24/2010',
#   'Published': False},
#  {'ProgramId': 896,
#   'Name': 'Pennsylvania - Green Power Purchasing',
#   'Code': 'PA05R',
#   'LastUpdate': '08/09/2011',
#   'Published': False},
#  {'ProgramId': 914,
#   'Name': 'Orcas Power & Light - Production Incentive',
#   'Code': 'WA14F',
#   'LastUpdate': '09/07/2011',
#   'Published': False},
#  {'ProgramId': 923,
#   'Name': 'Fort Collins - Electric Energy Supply Policy',
#   'Code': 'CO15R',
#   'LastUpdate': '05/25/2010',
#   'Published': False},
#  {'ProgramId': 939,
#   'Name': 'Renewable Energy Sales Tax Exemption',
#   'Code': 'WY04F',
#   'LastUpdate': '08/02/2012',
#   'Published': False},
#  {'ProgramId': 944,
#   'Name': 'Residential Renewable Energy Program',
#   'Code': 'WY05F',
#   'LastUpdate': '11/29/2010',
#   'Published': False},
#  {'ProgramId': 1046,
#   'Name': 'New Energy Technology Program',
#   'Code': 'CT09F',
#   'LastUpdate': '12/14/2011',
#   'Published': False},
#  {'ProgramId': 1087,
#   'Name': 'CEFIA - Residential Solar PV Rebate Program',
#   'Code': 'CT10F',
#   'LastUpdate': '03/05/2012',
#   'Published': False},
#  {'ProgramId': 1124,
#   'Name': 'Income Tax Subtraction for Energy-Efficient Residences',
#   'Code': 'AZ17F',
#   'LastUpdate': '04/21/2011',
#   'Published': False},
#  {'ProgramId': 1126,
#   'Name': 'Energy Efficiency Financing Program',
#   'Code': 'CA54F',
#   'LastUpdate': '05/06/2010',
#   'Published': False},
#  {'ProgramId': 1130,
#   'Name': 'State Buildings Energy Conservation Bond Program',
#   'Code': 'MT23F',
#   'LastUpdate': '03/02/2012',
#   'Published': False},
#  {'ProgramId': 1135,
#   'Name': 'Efficiency Maine Small Business Loan Program',
#   'Code': 'ME04F',
#   'LastUpdate': '12/20/2012',
#   'Published': False},
#  {'ProgramId': 1157,
#   'Name': 'NYSERDA - Energy Star Financing Program',
#   'Code': 'NY20F',
#   'LastUpdate': '01/20/2011',
#   'Published': False},
#  {'ProgramId': 1172,
#   'Name': 'Efficiency Vermont - Energy Efficient Motors and VFD Program',
#   'Code': 'VT14F',
#   'LastUpdate': '02/03/2011',
#   'Published': False},
#  {'ProgramId': 1173,
#   'Name': 'Efficiency Vermont - Vending Machine Controller Incentive',
#   'Code': 'VT15F',
#   'LastUpdate': '02/03/2011',
#   'Published': False},
#  {'ProgramId': 1189,
#   'Name': 'Rental Energy Loan Fund',
#   'Code': 'MN15F',
#   'LastUpdate': '04/03/2012',
#   'Published': False},
#  {'ProgramId': 1204,
#   'Name': 'Four-Day Sales Tax Exemption for Energy-Efficient Products',
#   'Code': 'GA05F',
#   'LastUpdate': '07/09/2010',
#   'Published': False},
#  {'ProgramId': 1211,
#   'Name': 'Steam Trap Rebate Program',
#   'Code': 'NC21F',
#   'LastUpdate': '07/25/2011',
#   'Published': False},
#  {'ProgramId': 1214,
#   'Name': 'Local Government Energy Loan Program',
#   'Code': 'TN05F',
#   'LastUpdate': '12/09/2011',
#   'Published': False},
#  {'ProgramId': 1216,
#   'Name': 'Efficiency Maine Renewable Energy Program',
#   'Code': 'ME08F',
#   'LastUpdate': '06/25/2013',
#   'Published': False},
#  {'ProgramId': 1220,
#   'Name': 'Alternative Energy Personal Property Tax Exemption',
#   'Code': 'MI18F',
#   'LastUpdate': '06/06/2013',
#   'Published': False},
#  {'ProgramId': 1228,
#   'Name': 'State Facility Energy Improvement Program',
#   'Code': 'ND09F',
#   'LastUpdate': '03/21/2013',
#   'Published': False},
#  {'ProgramId': 1233,
#   'Name': 'Small Multifamily Program',
#   'Code': 'OR34F',
#   'LastUpdate': '01/04/2013',
#   'Published': False},
#  {'ProgramId': 1236,
#   'Name': 'Operational Demonstration Program',
#   'Code': 'CT13F',
#   'LastUpdate': '07/11/2013',
#   'Published': False},
#  {'ProgramId': 1243,
#   'Name': 'Great River Energy (28 Member Cooperatives) - Solar-Electric (PV) Rebate Program',
#   'Code': 'MN17F',
#   'LastUpdate': '01/04/2010',
#   'Published': False},
#  {'ProgramId': 1259,
#   'Name': 'Austin Utilities - Solar Choice Program',
#   'Code': 'MN21F',
#   'LastUpdate': '09/01/2011',
#   'Published': False},
#  {'ProgramId': 1263,
#   'Name': 'On-Site Renewable DG Program',
#   'Code': 'CT16F',
#   'LastUpdate': '12/17/2012',
#   'Published': False},
#  {'ProgramId': 1269,
#   'Name': 'MassCEC - Sustainable Energy Economic Development (SEED) Initiative',
#   'Code': 'MA24F',
#   'LastUpdate': '02/01/2011',
#   'Published': False},
#  {'ProgramId': 1278,
#   'Name': 'ODOD - Advanced Energy Program Grants - Non-Residential Renewable Energy Incentive',
#   'Code': 'OH12F',
#   'LastUpdate': '11/08/2010',
#   'Published': False},
#  {'ProgramId': 1279,
#   'Name': 'ODOD - Advanced Energy Program Grants - Energy Efficiency for Manufacturers',
#   'Code': 'OH13F',
#   'LastUpdate': '11/08/2010',
#   'Published': False},
#  {'ProgramId': 1291,
#   'Name': 'Focus on Energy - Energy-Efficient Products Cash-Back Rewards',
#   'Code': 'WI18F',
#   'LastUpdate': '01/10/2012',
#   'Published': False},
#  {'ProgramId': 1304,
#   'Name': 'National Grid (Gas) - Solar Thermal Rebate Program',
#   'Code': 'NH05F',
#   'LastUpdate': '03/14/2011',
#   'Published': False},
#  {'ProgramId': 1313,
#   'Name': 'The United Illuminating Company - Small Business Energy Advantage Program',
#   'Code': 'CT20F',
#   'LastUpdate': '08/12/2010',
#   'Published': False},
#  {'ProgramId': 1315,
#   'Name': 'The United Illuminating Company - Energy Conscious Blueprint Grant Program',
#   'Code': 'CT22F',
#   'LastUpdate': '01/18/2011',
#   'Published': False},
#  {'ProgramId': 1316,
#   'Name': 'The United Illuminating Company - Energy Conscious Blueprint Rebate Program',
#   'Code': 'CT23F',
#   'LastUpdate': '08/12/2010',
#   'Published': False},
#  {'ProgramId': 1318,
#   'Name': 'The United Illuminating Company - MotorUp Commercial Rebate Program',
#   'Code': 'CT25F',
#   'LastUpdate': '06/28/2010',
#   'Published': False},
#  {'ProgramId': 1319,
#   'Name': 'The United Illuminating Company - Cool Choice Commercial Energy Efficiency Rebate Program',
#   'Code': 'CT26F',
#   'LastUpdate': '06/28/2010',
#   'Published': False},
#  {'ProgramId': 1320,
#   'Name': 'The United Illuminating Company - Energy Opportunities Program',
#   'Code': 'CT27F',
#   'LastUpdate': '08/12/2010',
#   'Published': False},
#  {'ProgramId': 1321,
#   'Name': 'Connecticut Light & Power - Energy Opportunities Efficiency Program',
#   'Code': 'CT28F',
#   'LastUpdate': '03/11/2010',
#   'Published': False},
#  {'ProgramId': 1322,
#   'Name': 'Connecticut Light & Power - Commercial Energy Efficiency Rebates',
#   'Code': 'CT29F',
#   'LastUpdate': '03/11/2010',
#   'Published': False},
#  {'ProgramId': 1323,
#   'Name': 'Connecticut Light & Power - Small Business Energy Advantage Program',
#   'Code': 'CT30F',
#   'LastUpdate': '05/04/2010',
#   'Published': False},
#  {'ProgramId': 1324,
#   'Name': 'Connecticut Light & Power - Small Business Energy Advantage Program',
#   'Code': 'CT31F',
#   'LastUpdate': '04/19/2011',
#   'Published': False},
#  {'ProgramId': 1325,
#   'Name': 'We Energies - Biogas Buy-Back Rate',
#   'Code': 'WI22F',
#   'LastUpdate': '01/04/2012',
#   'Published': False},
#  {'ProgramId': 1329,
#   'Name': 'The United Illuminating Company - Express Lighting Rebate Program',
#   'Code': 'CT34F',
#   'LastUpdate': '06/28/2010',
#   'Published': False},
#  {'ProgramId': 1330,
#   'Name': 'Connecticut Light & Power - Small Industrial and Commercial Energy Efficiency Loan Program',
#   'Code': 'CT35F',
#   'LastUpdate': '09/26/2010',
#   'Published': False},
#  {'ProgramId': 1339,
#   'Name': 'National Grid (Electric) - Residential Energy Efficiency Incentive Programs',
#   'Code': 'MA32F',
#   'LastUpdate': '05/12/2011',
#   'Published': False},
#  {'ProgramId': 1348,
#   'Name': 'National Grid - Energy Wise Program',
#   'Code': 'RI16F',
#   'LastUpdate': '03/08/2010',
#   'Published': False},
#  {'ProgramId': 1358,
#   'Name': 'Northern Utilities - Residential Energy Efficiency Programs',
#   'Code': 'NH06F',
#   'LastUpdate': '06/21/2010',
#   'Published': False},
#  {'ProgramId': 1375,
#   'Name': 'Unitil - Residential Energy Efficiency Programs',
#   'Code': 'MA37F',
#   'LastUpdate': '05/12/2011',
#   'Published': False},
#  {'ProgramId': 1379,
#   'Name': 'Unitil (Gas) - Business Energy Efficiency Programs',
#   'Code': 'MA38F',
#   'LastUpdate': '05/20/2011',
#   'Published': False},
#  {'ProgramId': 1383,
#   'Name': 'National Grid (Electric) - Commercial Energy Efficiency Incentive Programs',
#   'Code': 'MA41F',
#   'LastUpdate': '05/12/2011',
#   'Published': False},
#  {'ProgramId': 1393,
#   'Name': 'National Grid (Electric) - Small Business Energy Efficiency Program',
#   'Code': 'NH11F',
#   'LastUpdate': '05/18/2011',
#   'Published': False},
#  {'ProgramId': 1395,
#   'Name': 'NSTAR (Gas) - Residential Energy Efficiency Programs',
#   'Code': 'MA46F',
#   'LastUpdate': '05/12/2011',
#   'Published': False},
#  {'ProgramId': 1396,
#   'Name': 'NSTAR (Electric) - Construction Solutions Program',
#   'Code': 'MA47F',
#   'LastUpdate': '05/12/2011',
#   'Published': False},
#  {'ProgramId': 1399,
#   'Name': 'Connecticut Light & Power - Operation and Maintenance Program',
#   'Code': 'CT36F',
#   'LastUpdate': '05/04/2010',
#   'Published': False},
#  {'ProgramId': 1402,
#   'Name': 'National Grid (Gas) - Residential Energy Efficiency Programs',
#   'Code': 'MA50F',
#   'LastUpdate': '05/12/2011',
#   'Published': False},
#  {'ProgramId': 1404,
#   'Name': 'National Grid (Gas) - Residential Efficiency Rebate Program',
#   'Code': 'NH13F',
#   'LastUpdate': '04/30/2012',
#   'Published': False},
#  {'ProgramId': 1408,
#   'Name': 'Energy Solutions Business Appliance Rebates and Customized Incentives Program',
#   'Code': 'HI21F',
#   'LastUpdate': '03/15/2013',
#   'Published': False},
#  {'ProgramId': 1423,
#   'Name': 'Progress Energy Florida - Commercial Building Envelope Improvements Program',
#   'Code': 'FL22F',
#   'LastUpdate': '05/03/2010',
#   'Published': False},
#  {'ProgramId': 1478,
#   'Name': 'Yellow Springs Utilities - Net Metering',
#   'Code': 'OH09R',
#   'LastUpdate': '02/16/2010',
#   'Published': False},
#  {'ProgramId': 1485,
#   'Name': 'American Electric Power - Standard Offer Demand Response Program',
#   'Code': 'TX13F',
#   'LastUpdate': '05/29/2010',
#   'Published': False},
#  {'ProgramId': 1495,
#   'Name': 'We Energies - Direct Financial Incentives for Renewable Energy Projects',
#   'Code': 'WI24F',
#   'LastUpdate': '05/13/2011',
#   'Published': False},
#  {'ProgramId': 1496,
#   'Name': 'Colorado Springs Utilities - Home Improvement Financing',
#   'Code': 'CO17F',
#   'LastUpdate': '05/09/2011',
#   'Published': False},
#  {'ProgramId': 1501,
#   'Name': 'PPL Electric Utilities - Residential Energy Efficiency Rebate Program',
#   'Code': 'PA22F',
#   'LastUpdate': '03/17/2010',
#   'Published': False},
#  {'ProgramId': 1520,
#   'Name': 'Minnesota Power - Power Grant Energy Efficiency Rebate Program',
#   'Code': 'MN23F',
#   'LastUpdate': '06/21/2011',
#   'Published': False},
#  {'ProgramId': 1540,
#   'Name': 'Texas Gas Service - Food Service Equipment Program',
#   'Code': 'TX19F',
#   'LastUpdate': '02/29/2012',
#   'Published': False},
#  {'ProgramId': 1542,
#   'Name': 'Texas Gas Service - Commercial Water Heating Energy Efficiency Program',
#   'Code': 'TX21F',
#   'LastUpdate': '02/29/2012',
#   'Published': False},
#  {'ProgramId': 1548,
#   'Name': 'Texas-New Mexico Power Company - Energy Star Homes Market Transformation Program',
#   'Code': 'TX26F',
#   'LastUpdate': '08/19/2011',
#   'Published': False},
#  {'ProgramId': 1555,
#   'Name': 'We Energies (Electric) - Multifamily, Small Business and Nonprofit Efficiency Rebate Program',
#   'Code': 'WI32F',
#   'LastUpdate': '03/20/2012',
#   'Published': False},
#  {'ProgramId': 1567,
#   'Name': 'Appliance Efficiency Standards',
#   'Code': 'MA09R',
#   'LastUpdate': '03/25/2012',
#   'Published': False},
#  {'ProgramId': 1583,
#   'Name': 'Energy Efficiency Standards for Appliances',
#   'Code': 'VT05R',
#   'LastUpdate': '03/25/2012',
#   'Published': False},
#  {'ProgramId': 1600,
#   'Name': 'Solar Energy System Incentives Program',
#   'Code': 'FL33F',
#   'LastUpdate': '08/10/2011',
#   'Published': False},
#  {'ProgramId': 1607,
#   'Name': 'Renewable Energy Technologies Investment Tax Credit',
#   'Code': 'FL35F',
#   'LastUpdate': '04/24/2012',
#   'Published': False},
#  {'ProgramId': 1618,
#   'Name': 'Anaheim Public Utilities - Greener Cleaners Energy Efficiency Incentive Program',
#   'Code': 'CA78F',
#   'LastUpdate': '07/26/2010',
#   'Published': False},
#  {'ProgramId': 1622,
#   'Name': 'Anaheim Public Utilities - Residential Rehabilitation Loan and Grant Program',
#   'Code': 'CA80F',
#   'LastUpdate': '02/04/2011',
#   'Published': False},
#  {'ProgramId': 1627,
#   'Name': 'Avista Utilities (Electric) - Commercial Lighting Energy Efficiency Program',
#   'Code': 'WA35F',
#   'LastUpdate': '07/16/2013',
#   'Published': False},
#  {'ProgramId': 1628,
#   'Name': 'Avista Utilities - Commercial HVAC Variable Frequency Drive Initiative',
#   'Code': 'ID13F',
#   'LastUpdate': '05/25/2010',
#   'Published': False},
#  {'ProgramId': 1629,
#   'Name': 'Avista Utilities - Commercial HVAC Variable Frequency Drive Initiative',
#   'Code': 'WA36F',
#   'LastUpdate': '05/26/2010',
#   'Published': False},
#  {'ProgramId': 1648,
#   'Name': 'Idaho Power - Irrigation Efficiency Rewards Rebate Program',
#   'Code': 'ID22F',
#   'LastUpdate': '10/23/2011',
#   'Published': False},
#  {'ProgramId': 1667,
#   'Name': 'Avista Utilities (Gas) - Oregon Residential Weatherization Program',
#   'Code': 'OR41F',
#   'LastUpdate': '09/13/2011',
#   'Published': False},
#  {'ProgramId': 1690,
#   'Name': 'Glendale Water and Power - AC Energy Efficiency Rebate Program',
#   'Code': 'CA94F',
#   'LastUpdate': '01/11/2013',
#   'Published': False},
#  {'ProgramId': 1706,
#   'Name': 'Puget Sound Energy - Commercial Lighting & Lighting Controls Energy Efficiency Rebate Programs',
#   'Code': 'WA55F',
#   'LastUpdate': '08/13/2010',
#   'Published': False},
#  {'ProgramId': 1708,
#   'Name': 'Puget Sound Energy - Commercial HVAC Equipment Energy Efficiency Rebate Program',
#   'Code': 'WA56F',
#   'LastUpdate': '08/13/2010',
#   'Published': False},
#  {'ProgramId': 1712,
#   'Name': 'Puget Sound Energy - Portable Classroom Energy Efficient Controls Rebate Program',
#   'Code': 'WA59F',
#   'LastUpdate': '05/03/2012',
#   'Published': False},
#  {'ProgramId': 1785,
#   'Name': 'Electric Power Board - Home Developer Energy Efficiency Rebate Program',
#   'Code': 'GA07F',
#   'LastUpdate': '05/03/2010',
#   'Published': False},
#  {'ProgramId': 1802,
#   'Name': 'Belmont Municipal Light Department - Residential Energy Efficiency Rebate Program',
#   'Code': 'MA55F',
#   'LastUpdate': '01/26/2011',
#   'Published': False},
#  {'ProgramId': 1836,
#   'Name': 'Energy Reduction Plan for State Buildings',
#   'Code': 'MN12R',
#   'LastUpdate': '06/04/2010',
#   'Published': False},
#  {'ProgramId': 1901,
#   'Name': 'Riverside Public Utilities - Energy Efficiency Technology Grant Program',
#   'Code': 'CA115F',
#   'LastUpdate': '12/18/2012',
#   'Published': False},
#  {'ProgramId': 1904,
#   'Name': 'Roseville Electric - New Commercial Construction Energy Efficiency Rebate Program',
#   'Code': 'CA118F',
#   'LastUpdate': '12/06/2010',
#   'Published': False},
#  {'ProgramId': 1905,
#   'Name': 'Roseville Electric - Residential HVAC Financing Program',
#   'Code': 'CA119F',
#   'LastUpdate': '09/20/2011',
#   'Published': False},
#  {'ProgramId': 1908,
#   'Name': 'Energy Efficiency Standards for State Buildings',
#   'Code': 'NM11R',
#   'LastUpdate': '03/24/2010',
#   'Published': False},
#  {'ProgramId': 1936,
#   'Name': 'City of North St. Paul Electric Utility - Residential Energy Efficiency Rebate Program',
#   'Code': 'MN47F',
#   'LastUpdate': '08/06/2010',
#   'Published': False},
#  {'ProgramId': 1938,
#   'Name': 'City of North St. Paul Electric Utility - Commercial and Industrial Energy Efficiency Rebate Program',
#   'Code': 'MN49F',
#   'LastUpdate': '08/06/2010',
#   'Published': False},
#  {'ProgramId': 1945,
#   'Name': 'Owatonna Public Utilities - Commercial and Industrial Energy Efficiency Rebate Program',
#   'Code': 'MN56F',
#   'LastUpdate': '08/06/2010',
#   'Published': False},
#  {'ProgramId': 1963,
#   'Name': 'Covington Electric Cooperative Inc - Touchstone Energy Home Program',
#   'Code': 'AL18F',
#   'LastUpdate': '06/17/2010',
#   'Published': False},
#  {'ProgramId': 1992,
#   'Name': 'South Alabama Electric Cooperative - Residential Energy Efficiency Rebate Program',
#   'Code': 'AL28F',
#   'LastUpdate': '08/19/2011',
#   'Published': False},
#  {'ProgramId': 1997,
#   'Name': 'Winchester Utilities - Residential Energy Efficiency Rebate Program',
#   'Code': 'TN30F',
#   'LastUpdate': '11/30/2012',
#   'Published': False},
#  {'ProgramId': 2018,
#   'Name': 'Low-Income and Energy Efficiency Fund (LIEEF)',
#   'Code': 'MI07R',
#   'LastUpdate': '11/02/2012',
#   'Published': False},
#  {'ProgramId': 2020,
#   'Name': 'Austin Energy - Energy Miser Vending Products Program',
#   'Code': 'TX36F',
#   'LastUpdate': '09/19/2011',
#   'Published': False},
#  {'ProgramId': 2026,
#   'Name': 'Bryan Texas Utilities - Energy Efficiency Loan Program',
#   'Code': 'TX38F',
#   'LastUpdate': '04/02/2012',
#   'Published': False},
#  {'ProgramId': 2044,
#   'Name': 'Delta-Montrose Electric Association - Residential GeoExchange Loan Program',
#   'Code': 'CO36F',
#   'LastUpdate': '08/03/2010',
#   'Published': False},
#  {'ProgramId': 2046,
#   'Name': 'Holy Cross Energy - Commercial and Industrial Grant Program',
#   'Code': 'CO38F',
#   'LastUpdate': '11/01/2011',
#   'Published': False},
#  {'ProgramId': 2074,
#   'Name': 'Renewable Energy and Energy Efficiency Business Loan',
#   'Code': 'NH16F',
#   'LastUpdate': '04/25/2012',
#   'Published': False},
#  {'ProgramId': 2078,
#   'Name': 'Franklin County PUD - Residential Energy Efficiency Loan Program',
#   'Code': 'WA68F',
#   'LastUpdate': '05/28/2010',
#   'Published': False},
#  {'ProgramId': 2086,
#   'Name': 'Ferry County PUD #1 - Residential Energy Efficiency Rebate Programs',
#   'Code': 'WA70F',
#   'LastUpdate': '11/03/2011',
#   'Published': False},
#  {'ProgramId': 2104,
#   'Name': 'Aiken Electric Cooperative - EC Home Improvement Loan Program',
#   'Code': 'SC19F',
#   'LastUpdate': '08/03/2012',
#   'Published': False},
#  {'ProgramId': 2109,
#   'Name': 'Amicalola EMC - Energy Resource Conservation (ERC) Loan',
#   'Code': 'GA09F',
#   'LastUpdate': '06/25/2012',
#   'Published': False},
#  {'ProgramId': 2114,
#   'Name': 'KIUC - Efficient Appliance Rebate Program',
#   'Code': 'HI24F',
#   'LastUpdate': '03/25/2011',
#   'Published': False},
#  {'ProgramId': 2117,
#   'Name': 'Cass County Electric Cooperative - Residential Energy-Efficiency Loan Program',
#   'Code': 'ND10F',
#   'LastUpdate': '04/16/2012',
#   'Published': False},
#  {'ProgramId': 2125,
#   'Name': 'Brunswick EMC - Residential Energy Efficiency and Solar Water Heating Loan Program',
#   'Code': 'NC37F',
#   'LastUpdate': '08/09/2010',
#   'Published': False},
#  {'ProgramId': 2128,
#   'Name': 'Kit Carson Electric Cooperative - ETS System Rebate Program',
#   'Code': 'NM14F',
#   'LastUpdate': '08/12/2010',
#   'Published': False},
#  {'ProgramId': 2136,
#   'Name': 'Colton Public Utilities - PV Rebate Program',
#   'Code': 'CA130F',
#   'LastUpdate': '06/09/2011',
#   'Published': False},
#  {'ProgramId': 2192,
#   'Name': 'Berkeley Electric Cooperative - Earth Connect Geothermal Heat Pump Rebate Program',
#   'Code': 'SC20F',
#   'LastUpdate': '06/05/2012',
#   'Published': False},
#  {'ProgramId': 2198,
#   'Name': 'Mason County PUD 3 - Appliance Rebate Program',
#   'Code': 'WA79F',
#   'LastUpdate': '04/03/2013',
#   'Published': False},
#  {'ProgramId': 2201,
#   'Name': 'Pend Oreille PUD - Commercial and Industrial Rebate Program',
#   'Code': 'WA82F',
#   'LastUpdate': '08/17/2011',
#   'Published': False},
#  {'ProgramId': 2213,
#   'Name': 'Port Angeles Public Works & Utilities - Commercial and Industrial Energy Efficiency Rebate Program',
#   'Code': 'WA94F',
#   'LastUpdate': '08/13/2012',
#   'Published': False},
#  {'ProgramId': 2238,
#   'Name': 'Snohomish County PUD No 1 - Residential Weatherization & Heating Loan Program',
#   'Code': 'WA102F',
#   'LastUpdate': '07/11/2013',
#   'Published': False},
#  {'ProgramId': 2255,
#   'Name': 'Tennessee Clean Energy Technology Grant',
#   'Code': 'TN50F',
#   'LastUpdate': '02/12/2010',
#   'Published': False},
#  {'ProgramId': 2261,
#   'Name': 'Carroll EMC - Residential Energy Efficiency Loans',
#   'Code': 'GA12F',
#   'LastUpdate': '09/02/2010',
#   'Published': False},
#  {'ProgramId': 2275,
#   'Name': 'North Georgia EMC - Residential Heat Pump Loan Program',
#   'Code': 'GA26F',
#   'LastUpdate': '03/24/2010',
#   'Published': False},
#  {'ProgramId': 2276,
#   'Name': 'North Georgia EMC - Energy Efficient New Homes Program',
#   'Code': 'GA27F',
#   'LastUpdate': '03/24/2010',
#   'Published': False},
#  {'ProgramId': 2285,
#   'Name': 'Dakota Electric Association - Residential Energy Conservation Loan Program',
#   'Code': 'MN73F',
#   'LastUpdate': '02/23/2010',
#   'Published': False},
#  {'ProgramId': 2308,
#   'Name': 'South Kentucky RECC - Energy Efficiency Loan Program',
#   'Code': 'KY22F',
#   'LastUpdate': '06/15/2011',
#   'Published': False},
#  {'ProgramId': 2322,
#   'Name': 'Rental Rehabilitation Loan Program',
#   'Code': 'MN76F',
#   'LastUpdate': '01/10/2013',
#   'Published': False},
#  {'ProgramId': 2327,
#   'Name': 'Home Energy Loan Program (HELP)',
#   'Code': 'ME10F',
#   'LastUpdate': '02/16/2010',
#   'Published': False},
#  {'ProgramId': 2331,
#   'Name': 'Large-Customer Energy Analysis Program (LEAP)',
#   'Code': 'IL19F',
#   'LastUpdate': '07/11/2012',
#   'Published': False},
#  {'ProgramId': 2345,
#   'Name': 'Progress Energy Carolinas - Residential Energy Efficiency Loan Program',
#   'Code': 'NC43F',
#   'LastUpdate': '09/27/2011',
#   'Published': False},
#  {'ProgramId': 2352,
#   'Name': 'Roaring Fork Valley - Energy Efficient Appliance Program',
#   'Code': 'CO44F',
#   'LastUpdate': '02/19/2013',
#   'Published': False},
#  {'ProgramId': 2381,
#   'Name': 'Independence Light & Power - Renewable Energy Rebates',
#   'Code': 'IA35F',
#   'LastUpdate': '01/01/2011',
#   'Published': False},
#  {'ProgramId': 2382,
#   'Name': 'WPPI Energy - Renewable Energy Rebates (offered by seven MI utilities)',
#   'Code': 'MI19F',
#   'LastUpdate': '01/01/2011',
#   'Published': False},
#  {'ProgramId': 2389,
#   'Name': 'Petit Jean Electric Cooperative - Energy Efficiency Loan Program',
#   'Code': 'AR13F',
#   'LastUpdate': '08/23/2011',
#   'Published': False},
#  {'ProgramId': 2395,
#   'Name': 'City of St. George - Solar and Wind Rebate Program',
#   'Code': 'UT16F',
#   'LastUpdate': '07/07/2011',
#   'Published': False},
#  {'ProgramId': 2403,
#   'Name': 'U.S. Virgin Islands - Energy Efficiency & Renewable Energy Rebate Program',
#   'Code': 'VI01F',
#   'LastUpdate': '12/01/2011',
#   'Published': False},
#  {'ProgramId': 2418,
#   'Name': 'Douglas Electric Cooperative - Solar Rebate Program',
#   'Code': 'OR80F',
#   'LastUpdate': '05/13/2011',
#   'Published': False},
#  {'ProgramId': 2419,
#   'Name': 'Central Electric Cooperative - Solar Rebates',
#   'Code': 'OR81F',
#   'LastUpdate': '10/04/2011',
#   'Published': False},
#  {'ProgramId': 2424,
#   'Name': 'Pacific County PUD - Solar Water Heater Loan',
#   'Code': 'WA114F',
#   'LastUpdate': '09/10/2010',
#   'Published': False},
#  {'ProgramId': 2427,
#   'Name': 'Northwest Solar Cooperative - Green Tag Purchase',
#   'Code': 'OR86F',
#   'LastUpdate': '06/07/2010',
#   'Published': False},
#  {'ProgramId': 2428,
#   'Name': 'Northwest Solar Cooperative - Green Tag Purchase',
#   'Code': 'WA115F',
#   'LastUpdate': '06/07/2010',
#   'Published': False},
#  {'ProgramId': 2429,
#   'Name': 'Northwest Solar Cooperative - Green Tag Purchase',
#   'Code': 'ID29F',
#   'LastUpdate': '06/07/2010',
#   'Published': False},
#  {'ProgramId': 2430,
#   'Name': 'Northwest Solar Cooperative - Green Tag Purchase',
#   'Code': 'MT35F',
#   'LastUpdate': '06/07/2010',
#   'Published': False},
#  {'ProgramId': 2439,
#   'Name': 'Energy Star Procurement Requirement for Agencies',
#   'Code': 'DC08R',
#   'LastUpdate': '02/20/2013',
#   'Published': False},
#  {'ProgramId': 2441,
#   'Name': 'Indiana - Green Power Purchasing',
#   'Code': 'IN07R',
#   'LastUpdate': '01/07/2011',
#   'Published': False},
#  {'ProgramId': 2442,
#   'Name': 'Wild Rice Electric Cooperative - Residential Energy Efficiency Rebate Program',
#   'Code': 'MN77F',
#   'LastUpdate': '05/25/2011',
#   'Published': False},
#  {'ProgramId': 2459,
#   'Name': 'test program',
#   'Code': 'OR91F',
#   'LastUpdate': '04/13/2010',
#   'Published': False},
#  {'ProgramId': 2460,
#   'Name': 'City of Seattle - Density Bonus for Green Buildings',
#   'Code': 'WA116F',
#   'LastUpdate': '02/22/2012',
#   'Published': False},
#  {'ProgramId': 2461,
#   'Name': 'City of Seattle - Built Green Grant Program',
#   'Code': 'WA117F',
#   'LastUpdate': '09/14/2011',
#   'Published': False},
#  {'ProgramId': 2482,
#   'Name': 'U.S. Virgin Islands - Discretionary Grant Program',
#   'Code': 'VI02F',
#   'LastUpdate': '12/01/2011',
#   'Published': False},
#  {'ProgramId': 2491,
#   'Name': 'Town of Epping - Energy Efficiency and Sustainable Design Requirement',
#   'Code': 'NH08R',
#   'LastUpdate': '03/29/2010',
#   'Published': False},
#  {'ProgramId': 2518,
#   'Name': 'Kansas City Power & Light - Commercial/Industrial Energy Efficiency Rebate Program',
#   'Code': 'KS10F',
#   'LastUpdate': '02/21/2012',
#   'Published': False},
#  {'ProgramId': 2524,
#   'Name': 'King County - Commercial Green Building Grants Program',
#   'Code': 'WA124F',
#   'LastUpdate': '07/29/2011',
#   'Published': False},
#  {'ProgramId': 2609,
#   'Name': 'Energy Efficiency Rebate Program',
#   'Code': 'HI26F',
#   'LastUpdate': '03/15/2013',
#   'Published': False},
#  {'ProgramId': 2617,
#   'Name': 'Fairfax County - Green Power Purchase',
#   'Code': 'VA13R',
#   'LastUpdate': '04/13/2011',
#   'Published': False},
#  {'ProgramId': 2647,
#   'Name': 'Oncor Electric Delivery - Energy Star Homes Program',
#   'Code': 'TX51F',
#   'LastUpdate': '06/13/2012',
#   'Published': False},
#  {'ProgramId': 2648,
#   'Name': 'Oncor Electric Delivery - Home Energy Efficiency Program (Texas)',
#   'Code': 'TX52F',
#   'LastUpdate': '06/13/2012',
#   'Published': False},
#  {'ProgramId': 2659,
#   'Name': 'California Solar Initiative - Pilot Solar Water Heating Program',
#   'Code': 'CA145F',
#   'LastUpdate': '01/22/2010',
#   'Published': False},
#  {'ProgramId': 2687,
#   'Name': 'Paulding-Putnam EC - Residential Water Heat and HVAC Rebate Program',
#   'Code': 'IN40F',
#   'LastUpdate': '07/27/2010',
#   'Published': False},
#  {'ProgramId': 2691,
#   'Name': 'Paulding-Putnam EC - Residential Water Heater and HVAC Rebate Program',
#   'Code': 'OH21F',
#   'LastUpdate': '06/25/2010',
#   'Published': False},
#  {'ProgramId': 2711,
#   'Name': 'National Grid (Gas) - Solar Thermal Rebate Program (Metro New York)',
#   'Code': 'NY37F',
#   'LastUpdate': '04/21/2010',
#   'Published': False},
#  {'ProgramId': 2733,
#   'Name': 'Montgomery County - Wind Power Purchasing',
#   'Code': 'PA10R',
#   'LastUpdate': '04/06/2011',
#   'Published': False},
#  {'ProgramId': 2736,
#   'Name': 'NYSERDA - Clean Energy Business Growth and Development',
#   'Code': 'NY40F',
#   'LastUpdate': '06/16/2011',
#   'Published': False},
#  {'ProgramId': 2738,
#   'Name': 'NYSERDA - Renewable, Clean Energy, and Energy Efficient Product Manufacturing Incentive Program',
#   'Code': 'NY41F',
#   'LastUpdate': '06/16/2011',
#   'Published': False},
#  {'ProgramId': 2743,
#   'Name': 'PG&E - Residential New Construction Savings by Design Program',
#   'Code': 'CA149F',
#   'LastUpdate': '07/31/2010',
#   'Published': False},
#  {'ProgramId': 2747,
#   'Name': 'SDG&E - Residential New Construction Builder Efficiency Program',
#   'Code': 'CA151F',
#   'LastUpdate': '06/22/2010',
#   'Published': False},
#  {'ProgramId': 2761,
#   'Name': 'Distributed Generation as Combined Heat and Power (DG-CHP)',
#   'Code': 'NY43F',
#   'LastUpdate': '09/27/2012',
#   'Published': False},
#  {'ProgramId': 2816,
#   'Name': 'Clean Energy Development Fund (CEDF) Loan Program',
#   'Code': 'VT30F',
#   'LastUpdate': '02/14/2012',
#   'Published': False},
#  {'ProgramId': 2824,
#   'Name': 'New Energy Economic Development Grant Program',
#   'Code': 'CO145F',
#   'LastUpdate': '08/30/2011',
#   'Published': False},
#  {'ProgramId': 2829,
#   'Name': 'Howard County - Residential Solar and Geothermal Property Tax Credit',
#   'Code': 'MD23F',
#   'LastUpdate': '06/04/2012',
#   'Published': False},
#  {'ProgramId': 2849,
#   'Name': 'Banning Electric Department - Solar Support Program',
#   'Code': 'CA163F',
#   'LastUpdate': '05/19/2010',
#   'Published': False},
#  {'ProgramId': 2873,
#   'Name': 'City of Palo Alto Utilities - Renewable Energy Credit Purchase Program',
#   'Code': 'CA165F',
#   'LastUpdate': '06/10/2011',
#   'Published': False},
#  {'ProgramId': 2877,
#   'Name': 'North Carolina Green Business Fund',
#   'Code': 'NC47F',
#   'LastUpdate': '09/06/2011',
#   'Published': False},
#  {'ProgramId': 2897,
#   'Name': 'Missouri River Energy Service Member Utilities - Commercial and Industrial Efficiency Rebates',
#   'Code': 'IA43F',
#   'LastUpdate': '05/09/2013',
#   'Published': False},
#  {'ProgramId': 2900,
#   'Name': '30% Business Tax Credit for Solar',
#   'Code': 'VT31F',
#   'LastUpdate': '08/23/2011',
#   'Published': False},
#  {'ProgramId': 2906,
#   'Name': 'Energy Independence Fund Grant and Loan Program',
#   'Code': 'WI56F',
#   'LastUpdate': '01/13/2011',
#   'Published': False},
#  {'ProgramId': 2917,
#   'Name': 'WSU Extension Energy Program - Manufacturing Efficiency Program',
#   'Code': 'WA130F',
#   'LastUpdate': '08/13/2010',
#   'Published': False},
#  {'ProgramId': 2918,
#   'Name': 'LADWP - Small Business Direct Install Lighting Program',
#   'Code': 'CA171F',
#   'LastUpdate': '02/04/2011',
#   'Published': False},
#  {'ProgramId': 2921,
#   'Name': 'Sales Tax Exemption for Energy-Efficient Products',
#   'Code': 'WV07F',
#   'LastUpdate': '01/04/2011',
#   'Published': False},
#  {'ProgramId': 2929,
#   'Name': 'Orange County - Solar Hot Water Rebate Program',
#   'Code': 'FL65F',
#   'LastUpdate': '05/19/2010',
#   'Published': False},
#  {'ProgramId': 2936,
#   'Name': 'Local Insulation Rebate Programs',
#   'Code': 'CO150F',
#   'LastUpdate': '05/26/2010',
#   'Published': False},
#  {'ProgramId': 2942,
#   'Name': 'Xcel Energy - Experimental Advanced Renewable Energy Purchase Service',
#   'Code': 'WI57F',
#   'LastUpdate': '01/25/2013',
#   'Published': False},
#  {'ProgramId': 2946,
#   'Name': 'Bryan Texas Utilities - Solar PV Rebate Program',
#   'Code': 'TX64F',
#   'LastUpdate': '10/02/2012',
#   'Published': False},
#  {'ProgramId': 2947,
#   'Name': 'Bryan Texas Utilities - Solar Hot Water Rebate Program',
#   'Code': 'TX65F',
#   'LastUpdate': '05/07/2013',
#   'Published': False},
#  {'ProgramId': 2957,
#   'Name': 'We Energies - Solar Thermal Incentive Program',
#   'Code': 'WI58F',
#   'LastUpdate': '05/13/2011',
#   'Published': False},
#  {'ProgramId': 2962,
#   'Name': 'Virginia Natural Gas - Residential Energy Efficiency Rebate Program',
#   'Code': 'VA18F',
#   'LastUpdate': '03/05/2012',
#   'Published': False},
#  {'ProgramId': 2965,
#   'Name': 'Washington City Power - PV and Wind Rebate Program',
#   'Code': 'UT25F',
#   'LastUpdate': '03/04/2013',
#   'Published': False},
#  {'ProgramId': 2968,
#   'Name': 'Minnesota Energy Loan',
#   'Code': 'MN113F',
#   'LastUpdate': '04/12/2013',
#   'Published': False},
#  {'ProgramId': 2971,
#   'Name': 'Clean Energy Development Fund (CEDF) - Grant Program',
#   'Code': 'VT32F',
#   'LastUpdate': '10/29/2010',
#   'Published': False},
#  {'ProgramId': 2986,
#   'Name': 'Capital Investment Tax Credit for Clean Energy',
#   'Code': 'FL67F',
#   'LastUpdate': '04/20/2011',
#   'Published': False},
#  {'ProgramId': 2991,
#   'Name': 'PNM - Commercial Energy Efficiency Rebate Program',
#   'Code': 'NM23F',
#   'LastUpdate': '04/28/2010',
#   'Published': False},
#  {'ProgramId': 2999,
#   'Name': 'Solar Hot Water Rebate Program',
#   'Code': 'MN114F',
#   'LastUpdate': '01/03/2012',
#   'Published': False},
#  {'ProgramId': 3005,
#   'Name': 'Local Small Wind Rebate Programs',
#   'Code': 'CO153F',
#   'LastUpdate': '05/26/2010',
#   'Published': False},
#  {'ProgramId': 3017,
#   'Name': 'National Grid (Gas)â€“ Commercial Energy Efficiency Programs',
#   'Code': 'MA74F',
#   'LastUpdate': '05/12/2011',
#   'Published': False},
#  {'ProgramId': 3019,
#   'Name': 'National Grid  (Electric) - Commercial Energy Efficiency Rebate Programs (Upstate New York)',
#   'Code': 'NY49F',
#   'LastUpdate': '03/08/2010',
#   'Published': False},
#  {'ProgramId': 3027,
#   'Name': 'National Grid (Gas) - Solar Thermal Rebate Program',
#   'Code': 'RI26F',
#   'LastUpdate': '03/14/2011',
#   'Published': False},
#  {'ProgramId': 3046,
#   'Name': 'City of San Francisco - Green Building Requirement for City Buildings',
#   'Code': 'CA54R',
#   'LastUpdate': '09/28/2012',
#   'Published': False},
#  {'ProgramId': 3061,
#   'Name': 'Renewable Energy Business Development Grant Program',
#   'Code': 'IL27F',
#   'LastUpdate': '06/05/2013',
#   'Published': False},
#  {'ProgramId': 3072,
#   'Name': 'Model Ordinance for Wind Energy Systems',
#   'Code': 'MI14R',
#   'LastUpdate': '08/24/2011',
#   'Published': False},
#  {'ProgramId': 3087,
#   'Name': 'IID Energy - Agricultural Energy Efficiency Rebate Program',
#   'Code': 'CA177F',
#   'LastUpdate': '04/29/2010',
#   'Published': False},
#  {'ProgramId': 3091,
#   'Name': 'PPL Electric Utilities - LEED Certification Partnership Program',
#   'Code': 'PA29F',
#   'LastUpdate': '11/27/2011',
#   'Published': False},
#  {'ProgramId': 3092,
#   'Name': 'Energy Efficient Home Improvements Tax Credit',
#   'Code': 'MI20F',
#   'LastUpdate': '12/17/2012',
#   'Published': False},
#  {'ProgramId': 3110,
#   'Name': 'City of Berkeley - Financing Initiative for Renewable and Solar Technology (FIRST)',
#   'Code': 'CA179F',
#   'LastUpdate': '02/25/2010',
#   'Published': False},
#  {'ProgramId': 3114,
#   'Name': 'Energy Savings Tax Credit (Personal)',
#   'Code': 'IN50F',
#   'LastUpdate': '05/17/2011',
#   'Published': False},
#  {'ProgramId': 3116,
#   'Name': 'Energy Savings Tax Credit (Corporate)',
#   'Code': 'IN51F',
#   'LastUpdate': '05/17/2011',
#   'Published': False},
#  {'ProgramId': 3141,
#   'Name': 'Furnace and Boiler Replacement Rebate Program',
#   'Code': 'CT56F',
#   'LastUpdate': '04/25/2010',
#   'Published': False},
#  {'ProgramId': 3152,
#   'Name': 'Mecklenburg County - Green Permit Rebate Program',
#   'Code': 'NC52F',
#   'LastUpdate': '05/17/2010',
#   'Published': False},
#  {'ProgramId': 3160,
#   'Name': 'Puerto Rico - Solar Tax Credit (Personal)',
#   'Code': 'PR09F',
#   'LastUpdate': '08/08/2010',
#   'Published': False},
#  {'ProgramId': 3162,
#   'Name': 'Puerto Rico - Solar Tax Credit (Corporate)',
#   'Code': 'PR10F',
#   'LastUpdate': '08/08/2010',
#   'Published': False},
#  {'ProgramId': 3165,
#   'Name': 'Focus on Energy - Business & Marketing Grant',
#   'Code': 'WI59F',
#   'LastUpdate': '02/03/2010',
#   'Published': False},
#  {'ProgramId': 3177,
#   'Name': 'Town of Southampton - Photovoltaic (PV) Rebate Program',
#   'Code': 'NY53F',
#   'LastUpdate': '01/20/2010',
#   'Published': False},
#  {'ProgramId': 3186,
#   'Name': 'Richland Energy Services - Residential Solar Power Rebate Program',
#   'Code': 'WA137F',
#   'LastUpdate': '02/10/2012',
#   'Published': False},
#  {'ProgramId': 3190,
#   'Name': 'Renewable Energy Fund Grant Programs',
#   'Code': 'RI28F',
#   'LastUpdate': '01/10/2013',
#   'Published': False},
#  {'ProgramId': 3191,
#   'Name': 'Renewable Energy Fund Loan Programs',
#   'Code': 'RI29F',
#   'LastUpdate': '01/10/2013',
#   'Published': False},
#  {'ProgramId': 3198,
#   'Name': 'ODOD - Advanced Energy Program Grants - Residential Wind Energy Incentive',
#   'Code': 'OH27F',
#   'LastUpdate': '11/08/2010',
#   'Published': False},
#  {'ProgramId': 3199,
#   'Name': 'ODOD - Advanced Energy Program Grants - Multi-Family Residential Solar Thermal Incentive',
#   'Code': 'OH28F',
#   'LastUpdate': '11/08/2010',
#   'Published': False},
#  {'ProgramId': 3204,
#   'Name': 'Small Business Energy Efficiency Grant Program',
#   'Code': 'PA30F',
#   'LastUpdate': '06/22/2010',
#   'Published': False},
#  {'ProgramId': 3205,
#   'Name': 'Puget Sound Energy - Commercial Premium-Efficiency Motor Rebate Program',
#   'Code': 'WA138F',
#   'LastUpdate': '08/13/2010',
#   'Published': False},
#  {'ProgramId': 3215,
#   'Name': 'ODOD - Advanced Energy Program Grants - Non-Residential Distributed Energy Incentive',
#   'Code': 'OH29F',
#   'LastUpdate': '11/08/2010',
#   'Published': False},
#  {'ProgramId': 3221,
#   'Name': 'Renewable Energy Equipment Sales Tax Exemption',
#   'Code': 'FL78F',
#   'LastUpdate': '07/06/2010',
#   'Published': False},
#  {'ProgramId': 3228,
#   'Name': 'Preston Municipal Electric Utility - Renewable Energy Rebates',
#   'Code': 'IA47F',
#   'LastUpdate': '01/01/2011',
#   'Published': False},
#  {'ProgramId': 3229,
#   'Name': 'Maquoketa Municipal Electric Utility - Renewable Energy Rebates',
#   'Code': 'IA48F',
#   'LastUpdate': '01/01/2011',
#   'Published': False},
#  {'ProgramId': 3230,
#   'Name': 'Modesto Irrigation District - Residential High Efficiency Air Conditioning Loan Program',
#   'Code': 'CA184F',
#   'LastUpdate': '04/24/2012',
#   'Published': False},
#  {'ProgramId': 3236,
#   'Name': 'North Shore Gas - Chicagoland Natural Gas Savings Program',
#   'Code': 'IL35F',
#   'LastUpdate': '01/05/2010',
#   'Published': False},
#  {'ProgramId': 3239,
#   'Name': 'ODOD - Advanced Energy Program Grants - Residential Solar Photovoltaic Energy Incentive',
#   'Code': 'OH30F',
#   'LastUpdate': '11/08/2010',
#   'Published': False},
#  {'ProgramId': 3251,
#   'Name': 'Sales and Use Tax Refund for Qualified Community Wind Generators',
#   'Code': 'ME12F',
#   'LastUpdate': '12/14/2012',
#   'Published': False},
#  {'ProgramId': 3267,
#   'Name': 'Logan City Light and Power - PV Rebate Program',
#   'Code': 'UT28F',
#   'LastUpdate': '01/26/2011',
#   'Published': False},
#  {'ProgramId': 3270,
#   'Name': 'Renewable Energy Equipment Grant',
#   'Code': 'MN115F',
#   'LastUpdate': '02/07/2011',
#   'Published': False},
#  {'ProgramId': 3273,
#   'Name': 'Progress Energy Carolinas - Residential Energy Efficiency Loan Program',
#   'Code': 'SC33F',
#   'LastUpdate': '09/27/2011',
#   'Published': False},
#  {'ProgramId': 3274,
#   'Name': 'Progress Energy Carolinas - Home Advantage Builder Rebate Program',
#   'Code': 'NC53F',
#   'LastUpdate': '05/10/2012',
#   'Published': False},
#  {'ProgramId': 3280,
#   'Name': 'U.S. Department of Treasury - Renewable Energy Grants',
#   'Code': 'US53F',
#   'LastUpdate': '10/11/2012',
#   'Published': False},
#  {'ProgramId': 3287,
#   'Name': 'MichCon (Gas) - Residential Energy Efficiency (DTE Energy)',
#   'Code': 'MI23F',
#   'LastUpdate': '12/02/2010',
#   'Published': False},
#  {'ProgramId': 3293,
#   'Name': 'Kansas City Board of Public Utilities - Residential Energy Efficiency Rebate Program',
#   'Code': 'KS12F',
#   'LastUpdate': '03/29/2012',
#   'Published': False},
#  {'ProgramId': 3295,
#   'Name': 'Kansas City Board of Public Utilities - Homebuilder Energy Efficiency Rebate Program',
#   'Code': 'KS14F',
#   'LastUpdate': '05/04/2012',
#   'Published': False},
#  {'ProgramId': 3296,
#   'Name': 'Kansas City Board of Public Utilities - Subdivision Developer Energy Efficiency Rebate Program',
#   'Code': 'KS15F',
#   'LastUpdate': '03/29/2012',
#   'Published': False},
#  {'ProgramId': 3298,
#   'Name': 'Oncor Electric Delivery - Solar Water Heating Incentive Program',
#   'Code': 'TX70F',
#   'LastUpdate': '12/21/2011',
#   'Published': False},
#  {'ProgramId': 3299,
#   'Name': 'Boulder County - ClimateSmart Loan Program',
#   'Code': 'CO154F',
#   'LastUpdate': '09/26/2012',
#   'Published': False},
#  {'ProgramId': 3303,
#   'Name': 'Delaware Energy An$wers Home Performance Program',
#   'Code': 'DE08F',
#   'LastUpdate': '02/16/2010',
#   'Published': False},
#  {'ProgramId': 3309,
#   'Name': 'Alliant Energy (Wisconsin Power and Light) - Advanced Renewables Tariff',
#   'Code': 'WI67F',
#   'LastUpdate': '09/29/2010',
#   'Published': False},
#  {'ProgramId': 3317,
#   'Name': 'Questar Gas - Homebuilders Solar Assisted Gas Water Heating Rebate Program',
#   'Code': 'UT30F',
#   'LastUpdate': '03/16/2011',
#   'Published': False},
#  {'ProgramId': 3343,
#   'Name': 'Coast Electric Power Association - Heat Pump and Weatherization Loan Program',
#   'Code': 'MS16F',
#   'LastUpdate': '08/03/2011',
#   'Published': False},
#  {'ProgramId': 3361,
#   'Name': 'Kansas City Power & Light - Cool Homes Residential Rebate Program',
#   'Code': 'KS16F',
#   'LastUpdate': '09/02/2011',
#   'Published': False},
#  {'ProgramId': 3364,
#   'Name': 'Kansas City Power & Light - ENERGY STAR New Homes Rebate Program',
#   'Code': 'KS17F',
#   'LastUpdate': '09/02/2011',
#   'Published': False},
#  {'ProgramId': 3378,
# ...
#      'stateObject': {'id': 8,
#       'name': 'Connecticut',
#       'abbreviation': 'CT',
#       'is_territory': False},
#      'zip': '06051'},
#     'program': 1563,
#     'webVisible': True},
#    {'id': 4495,
#     'contact': {'id': 5680,
#      'firstName': '',
#      'lastName': '',
#      'email': 'DEEP.EnergyBureau@ct.gov',
#      'phone': '',
#      'organizationName': None,
#      'webVisibleDefault': True,
#      'websiteUrl': '',
#      'address': '79 Elm Street',
#      'city': 'Hartford',
#      'state': 8,
#      'stateObject': {'id': 8,
#       'name': 'Connecticut',
#       'abbreviation': 'CT',
#       'is_territory': False},
#      'zip': '06106'},
#     'program': 1563,
#     'webVisible': True}],
#   'ProgramParameters': [],
#   'Details': [{'id': 13,
#     'label': 'Equipment Requirements',
#     'value': 'Specified in standards',
#     'displayOrder': 0,
#     'templateId': 1},
#    {'id': 28,
#     'label': 'Test Methods',
#     'value': 'U.S. Department of Energy-approved test methods',
#     'displayOrder': 1,
#     'templateId': 2},
#    {'id': 43,
#     'label': 'Certification Requirements',
#     'value': 'Manufacturers certify to the Secretary of the Office of Policy and Management that products meet minimum efficiency standards',
#     'displayOrder': 2,
#     'templateId': 3},
#    {'id': 58,
#     'label': 'Review',
#     'value': 'Before July 2007 and biennially thereafter',
#     'displayOrder': 3,
#     'templateId': 4},
#    {'id': 73,
#     'label': 'Implementing Agency',
#     'value': 'Department of Energy and Environmental Protection',
#     'displayOrder': 4,
#     'templateId': 5}],
#   'Authorities': [{'id': 1008,
#     'code': 'Conn. Gen. Stat. Â§ 16a-48',
#     'website': 'http://www.cga.ct.gov/2011/pub/chap298.htm#Sec16a-48.htm',
#     'upload': {'key': None, 'fileName': None, 'url': None},
#     'effectiveDate': '',
#     'effectiveDateDisplay': '',
#     'effectiveText': '',
#     'enactedDate': '',
#     'enactedDateDisplay': '',
#     'enactedText': '',
#     'expiredDate': '',
#     'expiredDateDisplay': '',
#     'expiredText': ''},
#    {'id': 2980,
#     'code': 'S.B.1243 (Public Act 11-80)',
#     'website': 'http://www.cga.ct.gov/2011/ACT/PA/2011PA-00080-R00SB-01243-PA.htm',
#     'upload': {'key': None, 'fileName': None, 'url': None},
#     'effectiveDate': '',
#     'effectiveDateDisplay': '07/01/2011',
#     'effectiveText': '07/01/2011',
#     'enactedDate': '',
#     'enactedDateDisplay': '07/01/2011',
#     'enactedText': '07/01/2011',
#     'expiredDate': '',
#     'expiredDateDisplay': '',
#     'expiredText': ''}],
#   'FromSir': False},
#  {'ProgramId': 1564,
#   'Name': 'Appliance Energy Efficiency Standards',
#   'Code': 'MD10R',
#   'LastUpdate': '10/17/2014',
#   'Published': True,
#   'State': 'Maryland',
#   'ImplementingSectorId': 1,
#   'ImplementingSectorName': 'State',
#   'CategoryId': 2,
#   'CategoryName': 'Regulatory Policy',
#   'TypeId': 62,
#   'TypeName': 'Appliance/Equipment Efficiency Standards',
#   'WebsiteUrl': 'http://www.energy.state.md.us/policy/standards.html',
#   'Administrator': '',
#   'FundingSource': '',
#   'Budget': '',
#   'StartDate': '',
#   'EndDate': '',
#   'Utilities': [],
#   'Counties': [],
#   'Cities': [],
#   'ZipCodes': [],
#   'Technologies': [{'id': 111,
#     'name': 'Other EE',
#     'category': 'Other',
#     'categoryId': 13,
#     'energyCategoryId': 2},
#    {'id': 120,
#     'name': 'Food Service Equipment',
#     'category': 'Other',
#     'categoryId': 13,
#     'energyCategoryId': 2}],
#   'Sectors': [],
#   'Contacts': [{'id': 4496,
#     'contact': {'id': 617,
#      'firstName': 'Public',
#      'lastName': 'Information Officer - MEA',
#      'email': 'dlinfo_mea@maryland.gov',
#      'phone': '(410) 260-7655',
#      'organizationName': 'Maryland Energy Administration',
#      'webVisibleDefault': True,
#      'websiteUrl': 'http://www.energy.state.md.us',
#      'address': '60 West Street, 3rd Floor',
#      'city': 'Annapolis',
#      'state': 24,
#      'stateObject': {'id': 24,
#       'name': 'Maryland',
#       'abbreviation': 'MD',
#       'is_territory': False},
#      'zip': '21401'},
#     'program': 1564,
#     'webVisible': True}],
#   'ProgramParameters': [],
#   'Details': [{'id': 14,
#     'label': 'Equipment Requirements',
#     'value': 'Specified in standards',
#     'displayOrder': 0,
#     'templateId': 1},
#    {'id': 29,
#     'label': 'Test Methods',
#     'value': 'Must be consistent with the testing standards established by the federal government in the Energy Policy Act of 2005',
#     'displayOrder': 1,
#     'templateId': 2},
#    {'id': 44,
#     'label': 'Certification Requirements',
#     'value': 'Manufacturers certify to the Maryland Energy Administration that specified products comply with minimum efficiency standards',
#     'displayOrder': 2,
#     'templateId': 3},
#    {'id': 59,
#     'label': 'Review',
#     'value': 'Every 2 years',
#     'displayOrder': 3,
#     'templateId': 4},
#    {'id': 74,
#     'label': 'Implementing Agency',
#     'value': 'Maryland Energy Administration',
#     'displayOrder': 4,
#     'templateId': 5}],
#   'Authorities': [{'id': 1009,
#     'code': 'COMAR 14.26.03 Maryland Energy Efficiency Standards',
#     'website': 'http://www.dsd.state.md.us/comar/SubtitleSearch.aspx?search=14.26.03.*',
#     'upload': {'key': None, 'fileName': None, 'url': None},
#     'effectiveDate': '',
#     'effectiveDateDisplay': '06/19/2006',
#     'effectiveText': '06/19/2006',
#     'enactedDate': '',
#     'enactedDateDisplay': '',
#     'enactedText': '',
#     'expiredDate': '',
#     'expiredDateDisplay': '',
#     'expiredText': ''},
#    {'id': 1584,
#     'code': 'Md. Code: State Government Â§ 9-2006',
#     'website': 'http://mgaleg.maryland.gov/webmga/frmStatutesText.aspx?article=gsg&section=9-2006&ext=html&session=2015RS&tab=subject5',
#     'upload': {'key': None, 'fileName': None, 'url': None},
#     'effectiveDate': '',
#     'effectiveDateDisplay': '02/19/2004 (amendments effective 07/01/2007)',
#     'effectiveText': '02/19/2004 (amendments effective 07/01/2007)',
#     'enactedDate': '',
#     'enactedDateDisplay': '',
#     'enactedText': '',
#     'expiredDate': '',
#     'expiredDateDisplay': '',
#     'expiredText': ''}],
#   'FromSir': False},
#  {'ProgramId': 1568,
#   'Name': 'Energy Efficiency Product Standards',
#   'Code': 'NJ12R',
#   'LastUpdate': '10/08/2014',
#   'Published': True,
#   'State': 'New Jersey',
#   'ImplementingSectorId': 1,
#   'ImplementingSectorName': 'State',
#   'CategoryId': 2,
#   'CategoryName': 'Regulatory Policy',
#   'TypeId': 62,
#   'TypeName': 'Appliance/Equipment Efficiency Standards',
#   'WebsiteUrl': 'http://www.state.nj.us/bpu/',
#   'Administrator': None,
#   'FundingSource': None,
#   'Budget': None,
#   'StartDate': '',
#   'EndDate': '',
#   'Utilities': [],
#   'Counties': [],
#   'Cities': [],
#   'ZipCodes': [],
#   'Technologies': [],
#   'Sectors': [],
#   'Contacts': [{'id': 4197,
#     'contact': {'id': 1907,
#      'firstName': 'Public',
#      'lastName': 'Information',
#      'email': '',
#      'phone': '(201) 648-3717',
#      'organizationName': 'New Jersey Board of Public Utilities',
#      'webVisibleDefault': True,
#      'websiteUrl': 'http://www.state.nj.us/bpu/',
#      'address': '2 Gateway Center',
#      'city': 'Newark',
#      'state': 35,
#      'stateObject': {'id': 35,
#       'name': 'New Jersey',
#       'abbreviation': 'NJ',
#       'is_territory': False},
#      'zip': '07102'},
#     'program': 1568,
#     'webVisible': True}],
#   'ProgramParameters': [],
#   'Details': [{'id': 11,
#     'label': 'Equipment Requirements',
#     'value': 'All state-developed standards have been preempted by federal regulation',
#     'displayOrder': 0,
#     'templateId': 1},
#    {'id': 26,
#     'label': 'Test Methods',
#     'value': 'Standard New Jersey building code or United States Department of Energy approved test methods',
#     'displayOrder': 1,
#     'templateId': 2},
#    {'id': 41,
#     'label': 'Certification Requirements',
#     'value': 'Manufacturers certify to the New Jersey Commissioner of Environmental Protection that specified products meet minimum efficiency standards.  \r\n',
#     'displayOrder': 2,
#     'templateId': 3},
#    {'id': 56,
#     'label': 'Review',
#     'value': 'Not specified',
#     'displayOrder': 3,
#     'templateId': 4},
#    {'id': 71,
#     'label': 'Implementing Agency',
#     'value': 'New Jersey Board of Public Utilities and the Commissioner of Environmental Protection',
#     'displayOrder': 4,
#     'templateId': 5}],
#   'Authorities': [{'id': 1015,
#     'code': 'N.J. Stat. Â§ 48:3-99 et seq.',
#     'website': '',
#     'upload': {'key': None, 'fileName': None, 'url': None},
#     'effectiveDate': '',
#     'effectiveDateDisplay': '',
#     'effectiveText': '',
#     'enactedDate': '',
#     'enactedDateDisplay': '',
#     'enactedText': '',
#     'expiredDate': '',
#     'expiredDateDisplay': '',
#     'expiredText': ''},
#    {'id': 1696,
#     'code': 'N.J.A.C. 14:8-7.1 et seq.',
#     'website': '',
#     'upload': {'key': None, 'fileName': None, 'url': None},
#     'effectiveDate': '',
#     'effectiveDateDisplay': '01/07/2008',
#     'effectiveText': '01/07/2008',
#     'enactedDate': '',
#     'enactedDateDisplay': '',
#     'enactedText': '',
#     'expiredDate': '',
#     'expiredDateDisplay': '',
#     'expiredText': ''}],
#   'FromSir': False},
#  {'ProgramId': 1569,
#   'Name': 'Appliance and Equipment Energy Efficiency Standards',
#   'Code': 'NY09R',
#   'LastUpdate': '07/10/2015',
#   'Published': True,
#   'State': 'New York',
#   'ImplementingSectorId': 1,
#   'ImplementingSectorName': 'State',
#   'CategoryId': 2,
#   'CategoryName': 'Regulatory Policy',
#   'TypeId': 62,
#   'TypeName': 'Appliance/Equipment Efficiency Standards',
#   'WebsiteUrl': '',
#   'Administrator': None,
#   'FundingSource': None,
#   'Budget': None,
#   'StartDate': '',
#   'EndDate': '',
#   'Utilities': [],
#   'Counties': [],
#   'Cities': [],
#   'ZipCodes': [],
#   'Technologies': [{'id': 111,
#     'name': 'Other EE',
#     'category': 'Other',
#     'categoryId': 13,
#     'energyCategoryId': 2},
#    {'id': 136,
#     'name': 'Pool Pumps',
#     'category': 'Other',
#     'categoryId': 13,
#     'energyCategoryId': 2}],
#   'Sectors': [],
#   'Contacts': [{'id': 4199,
#     'contact': {'id': 1705,
#      'firstName': 'Public',
#      'lastName': 'Information - NYSERDA',
#      'email': 'info@nyserda.ny.gov',
#      'phone': '(866) 697-3732',
#      'organizationName': 'New York State Energy Research and Developmen',
#      'webVisibleDefault': True,
#      'websiteUrl': 'http://www.nyserda.ny.gov/',
#      'address': '17 Columbia Circle',
#      'city': 'Albany',
#      'state': 37,
#      'stateObject': {'id': 37,
#       'name': 'New York',
#       'abbreviation': 'NY',
#       'is_territory': False},
#      'zip': '12203-6399'},
#     'program': 1569,
#     'webVisible': True},
#    {'id': 4200,
#     'contact': {'id': 5555,
#      'firstName': 'Priscilla',
#      'lastName': 'Richards',
#      'email': 'priscilla.richards@nyserda.ny.gov',
#      'phone': '(518) 862-1090',
#      'organizationName': None,
#      'webVisibleDefault': True,
#      'websiteUrl': '',
#      'address': '',
#      'city': '',
#      'state': None,
#      'stateObject': {'id': None},
#      'zip': ''},
#     'program': 1569,
#     'webVisible': False}],
#   'ProgramParameters': [],
#   'Details': [{'id': 12,
#     'label': 'Equipment Requirements',
#     'value': 'Specified in Standards\r\n\r\n',
#     'displayOrder': 0,
#     'templateId': 1},
#    {'id': 27,
#     'label': 'Test Methods',
#     'value': 'To be determined',
#     'displayOrder': 1,
#     'templateId': 2},
#    {'id': 42,
#     'label': 'Certification Requirements',
#     'value': 'To be determined',
#     'displayOrder': 2,
#     'templateId': 3},
#    {'id': 57,
#     'label': 'Review',
#     'value': 'Not specified',
#     'displayOrder': 3,
#     'templateId': 4},
#    {'id': 72,
#     'label': 'Implementing Agency',
#     'value': 'New York Secretary of State\r\n',
#     'displayOrder': 4,
#     'templateId': 5}],
#   'Authorities': [{'id': 1016,
#     'code': 'NY CLS Energy, Article 16 § 102 et seq.',
#     'website': 'http://public.leginfo.state.ny.us/',
#     'upload': {'key': None, 'fileName': None, 'url': None},
#     'effectiveDate': '',
#     'effectiveDateDisplay': '',
#     'effectiveText': '',
#     'enactedDate': '',
#     'enactedDateDisplay': '',
#     'enactedText': '',
#     'expiredDate': '',
#     'expiredDateDisplay': '',
#     'expiredText': ''},
#    {'id': 4231,
#     'code': 'Article 5 § 5-108a (Efficiency standards for appliances for state procurement)',
#     'website': 'http://www.nyserda.ny.gov/Communities-and-Governments/Local-Governments/Energy-Efficient-Equipment-Standards-for-State-Purchasing',
#     'upload': {'key': None, 'fileName': None, 'url': None},
#     'effectiveDate': '',
#     'effectiveDateDisplay': None,
#     'effectiveText': None,
#     'enactedDate': '',
#     'enactedDateDisplay': None,
#     'enactedText': None,
#     'expiredDate': '',
#     'expiredDateDisplay': None,
#     'expiredText': None}],
#   'FromSir': False},
#  {'ProgramId': 1579,
#   'Name': 'Appliance and Equipment Energy Efficiency Standards',
#   'Code': 'OR19R',
#   'LastUpdate': '12/21/2015',
#   'Published': True,
#   'State': 'Oregon',
#   'ImplementingSectorId': 1,
#   'ImplementingSectorName': 'State',
#   'CategoryId': 2,
#   'CategoryName': 'Regulatory Policy',
#   'TypeId': 62,
#   'TypeName': 'Appliance/Equipment Efficiency Standards',
#   'WebsiteUrl': 'http://www.oregon.gov/energy/cons/stateregulatedappliancestandards.shtml',
#   'Administrator': '',
#   'FundingSource': '',
#   'Budget': '',
#   'StartDate': '',
#   'EndDate': '',
#   'Utilities': [],
#   'Counties': [],
#   'Cities': [],
#   'ZipCodes': [],
#   'Technologies': [{'id': 111,
#     'name': 'Other EE',
#     'category': 'Other',
#     'categoryId': 13,
#     'energyCategoryId': 2},
#    {'id': 139,
#     'name': 'Commercial Refrigeration Equipment',
#     'category': 'Other',
#     'categoryId': 13,
#     'energyCategoryId': 2}],
#   'Sectors': [],
#   'Contacts': [{'id': 2658,
#     'contact': {'id': 5418,
#      'firstName': 'Appliance Standards',
#      'lastName': 'Program Manager',
#      'email': 'energyweb.incoming@state.or.us',
#      'phone': '(503) 378-4040',
#      'organizationName': None,
#      'webVisibleDefault': True,
#      'websiteUrl': '',
#      'address': '',
#      'city': '',
#      'state': None,
#      'stateObject': {'id': None},
#      'zip': ''},
#     'program': 1579,
#     'webVisible': True}],
#   'ProgramParameters': [],
#   'Details': [{'id': 2,
#     'label': 'Equipment Requirements',
#     'value': 'Specified in standards\r\n\r\n',
#     'displayOrder': 0,
#     'templateId': 1},
#    {'id': 17,
#     'label': 'Test Methods',
#     'value': 'Specified in standards',
#     'displayOrder': 1,
#     'templateId': 2},
#    {'id': 32,
#     'label': 'Certification Requirements',
#     'value': 'Manufacturers certify to the Oregon State Department of Energy that products meet efficiency standards. The Department establishes rules governing the certification of these products and may coordinate with the certification programs of other states and federal agencies with similar standards.',
#     'displayOrder': 2,
#     'templateId': 3},
#    {'id': 47,
#     'label': 'Review',
#     'value': 'State Department of Energy periodically reviews the standards and reports to the Legislative Assembly',
#     'displayOrder': 3,
#     'templateId': 4},
#    {'id': 62,
#     'label': 'Implementing Agency',
#     'value': 'Oregon State Department of Energy',
#     'displayOrder': 4,
#     'templateId': 5}],
#   'Authorities': [{'id': 1018,
#     'code': 'ORS 469.229 et seq.',
#     'website': 'https://www.oregonlegislature.gov/bills_laws/lawsstatutes/2013ors469.html',
#     'upload': {'key': None, 'fileName': None, 'url': None},
#     'effectiveDate': '',
#     'effectiveDateDisplay': '',
#     'effectiveText': '',
#     'enactedDate': '',
#     'enactedDateDisplay': '',
#     'enactedText': '',
#     'expiredDate': '',
#     'expiredDateDisplay': '',
#     'expiredText': ''},
#    {'id': 1856,
#     'code': 'OAR 330-092-0005 et seq.',
#     'website': 'http://arcweb.sos.state.or.us/pages/rules/oars_300/oar_330/330_092.html',
#     'upload': {'key': None, 'fileName': None, 'url': None},
#     'effectiveDate': '',
#     'effectiveDateDisplay': '3/1/2008',
#     'effectiveText': '3/1/2008',
#     'enactedDate': '',
#     'enactedDateDisplay': '3/1/2008',
#     'enactedText': '3/1/2008',
#     'expiredDate': '',
#     'expiredDateDisplay': '',
#     'expiredText': ''}],
#   'FromSir': False},
#  ...]

# %%
#Above here, I merged the three json files into one file called "alldata"
#This new file does not include any metadata, which can be found in the separate and original three files

# %%
#Next I will clean the data some
#I will make sure all dictionaries have the same data keys

# %%
def getkeywords(row):
    return set(row.keys())

# %%
keywords = list(map(getkeywords, alldata))
#keywords

# %%
headers = reduce(lambda setA, setB: setA.union(setB), keywords)
headers
# Out:
# {'Administrator',
#  'Authorities',
#  'Budget',
#  'CategoryId',
#  'CategoryName',
#  'Cities',
#  'Code',
#  'Contacts',
#  'Counties',
#  'Details',
#  'EndDate',
#  'FromSir',
#  'FundingSource',
#  'ImplementingSectorId',
#  'ImplementingSectorName',
#  'LastUpdate',
#  'Name',
#  'ProgramId',
#  'ProgramParameters',
#  'Published',
#  'Sectors',
#  'StartDate',
#  'State',
#  'Technologies',
#  'TypeId',
#  'TypeName',
#  'Utilities',
#  'WebsiteUrl',
#  'ZipCodes'}

# %%
def cleanit(row):
    for header in headers:
        if header in row:
            pass
        else:
            row[header] = "no data included"
    return row

# %%
alldata_clean = []
for row in alldata:
    alldata_clean.append(cleanit(row))
    
#alldata_clean

# %%
def filterfunction(input_row):
    for header in headers:
        cell_value = input_row[header]
        searchterm = "Matching"
        if isinstance(cell_value, str) and searchterm in cell_value:
            return True
    return False

# %%
# *** The "searchterm" must be changed to match each of the
#     following codes***

# %%
# ***check keyword in filterfuntion before running***

Innovation_in_cleaned_data = list(filter(filterfunction, alldata_clean))
Innovation_ids = list(map(itemgetter('ProgramId'), Innovation_in_cleaned_data))
Innovation_names = list(map(itemgetter('Name'), Innovation_in_cleaned_data))
Innovation_ids, Innovation_names

# %%
# ***check keyword in filterfuntion before running***

innovation_in_cleaned_data = list(filter(filterfunction, alldata_clean))
innovation_ids = list(map(itemgetter('ProgramId'), innovation_in_cleaned_data))
innovation_names = list(map(itemgetter('Name'), innovation_in_cleaned_data))
innovation_ids, innovation_names

# %%
#ProgramIds for key term "Innovation":
#[3678, 3758, 4327, 4931, 5122, 1646, 3266, 3597, 4848, 4856, 22074]

#Names for key term "Innovation":
#['Edison Innovation Clean Energy Fund',
#  'Lincoln Electric System (LES) - Commercial and Industrial Energy-Efficiency Innovation Grant',
#  'Tennessee Solar Institute - Solar Innovation Grant Program',
#  'Innovation Incentive Program',
#  'NYSERDA - Innovation in Manufacturing Clean Energy Technologies',
#  'Community Innovations Grant Program',
#  'Edison Innovation Clean Energy Manufacturing Fund - Grants and Loans',
#  'Guidance for Local Wind Energy Ordinances',
#  'Edison Innovation Green Growth Fund Loans',
#  'Small Wind Innovation Zone Program and Model Ordinance',
#  'Energy Innovation Grant Program']


# This list includes both capital and lowercase "Innovation"

# %%
# ***check keyword in filterfuntion before running***

# %%
# ***check keyword in filterfuntion before running***

innovate_in_cleaned_data = list(filter(filterfunction, alldata_clean))
innovate_ids = list(map(itemgetter('ProgramId'), innovate_in_cleaned_data))
innovate_names = list(map(itemgetter('Name'), innovate_in_cleaned_data))
innovate_ids, innovate_names


# "innovate" does not exist in the data

# %%
# ***check keyword in filterfuntion before running***

Innovate_in_cleaned_data = list(filter(filterfunction, alldata_clean))
Innovate_ids = list(map(itemgetter('ProgramId'), Innovate_in_cleaned_data))
Innovate_names = list(map(itemgetter('Name'), Innovate_in_cleaned_data))
Innovate_ids, Innovate_names

#"Innovate" does not exist in the data

# %%
# ***check keyword in filterfuntion before running***

diversity_in_cleaned_data = list(filter(filterfunction, alldata_clean))
diversity_ids = list(map(itemgetter('ProgramId'), diversity_in_cleaned_data))
diversity_names = list(map(itemgetter('Name'), diversity_in_cleaned_data))
diversity_ids, diversity_names

# "diversity" does not exist in the data

# %%
# ***check keyword in filterfuntion before running***

Diversity_in_cleaned_data = list(filter(filterfunction, alldata_clean))
Diversity_ids = list(map(itemgetter('ProgramId'), Diversity_in_cleaned_data))
Diversity_names = list(map(itemgetter('Name'), Diversity_in_cleaned_data))
Diversity_ids, Diversity_names

# "Diversity" does not exist in the data

# %%
# ***check keyword in filterfuntion before running***

diverse_in_cleaned_data = list(filter(filterfunction, alldata_clean))
diverse_ids = list(map(itemgetter('ProgramId'), diverse_in_cleaned_data))
diverse_names = list(map(itemgetter('Name'), diverse_in_cleaned_data))
diverse_ids, diverse_names

# %%
# ***check keyword in filterfuntion before running***

Diverse_in_cleaned_data = list(filter(filterfunction, alldata_clean))
Diverse_ids = list(map(itemgetter('ProgramId'), Diverse_in_cleaned_data))
Diverse_names = list(map(itemgetter('Name'), Diverse_in_cleaned_data))
Diverse_ids, Diverse_names

# %%
# ProgramIds for key term "diverse":
# [2266, 4828, 21032]
# Names of Programs for key term "diverse":
#['Diverse Power - Energy Efficient New Construction Rebate Programs',
#  'Diverse Power - Energy Efficient Existing Homes Rebate Program',
#  'Diverse Power - Green Power']

# This includes results for both upper and lower case "Diverse"

# %%
# ***check keyword in filterfuntion before running***

woman_in_cleaned_data = list(filter(filterfunction, alldata_clean))
woman_ids = list(map(itemgetter('ProgramId'), woman_in_cleaned_data))
woman_names = list(map(itemgetter('Name'), woman_in_cleaned_data))
woman_ids, woman_names

# "woman" does not exist in the data

# %%
# ***check keyword in filterfuntion before running***

Woman_in_cleaned_data = list(filter(filterfunction, alldata_clean))
Woman_ids = list(map(itemgetter('ProgramId'), Woman_in_cleaned_data))
Woman_names = list(map(itemgetter('Name'), Woman_in_cleaned_data))
Woman_ids, Woman_names

# "Woman" does not exist in the data

# %%
# ***check keyword in filterfuntion before running***

women_in_cleaned_data = list(filter(filterfunction, alldata_clean))
women_ids = list(map(itemgetter('ProgramId'), women_in_cleaned_data))
women_names = list(map(itemgetter('Name'), women_in_cleaned_data))
women_ids, women_names

# "women" does not exist in the data

# %%
# ***check keyword in filterfuntion before running***

Women_in_cleaned_data = list(filter(filterfunction, alldata_clean))
Women_ids = list(map(itemgetter('ProgramId'), Women_in_cleaned_data))
Women_names = list(map(itemgetter('Name'), Women_in_cleaned_data))
Women_ids, Women_names

# "Women" does not exist in the data

# %%
# ***check keyword in filterfuntion before running***

statematch_in_cleaned_data = list(filter(filterfunction, alldata_clean))
statematch_ids = list(map(itemgetter('ProgramId'), statematch_in_cleaned_data))
statematch_names = list(map(itemgetter('Name'), statematch_in_cleaned_data))
statematch_ids, statematch_names

# %%
# ***check keyword in filterfuntion before running***

Statematch_in_cleaned_data = list(filter(filterfunction, alldata_clean))
Statematch_ids = list(map(itemgetter('ProgramId'), Statematch_in_cleaned_data))
Statematch_names = list(map(itemgetter('Name'), Statematch_in_cleaned_data))
Statematch_ids, Statematch_names

# %%
# ***check keyword in filterfuntion before running***

stateMatch_in_cleaned_data = list(filter(filterfunction, alldata_clean))
stateMatch_ids = list(map(itemgetter('ProgramId'), stateMatch_in_cleaned_data))
stateMatch_names = list(map(itemgetter('Name'), stateMatch_in_cleaned_data))
stateMatch_ids, stateMatch_names

# %%
# ***check keyword in filterfuntion before running***

StateMatch_in_cleaned_data = list(filter(filterfunction, alldata_clean))
StateMatch_ids = list(map(itemgetter('ProgramId'), StateMatch_in_cleaned_data))
StateMatch_names = list(map(itemgetter('Name'), StateMatch_in_cleaned_data))
StateMatch_ids, StateMatch_names

# %%
# "State Match" does not exist in the data in any capitalization form

# %%
# ***check keyword in filterfuntion before running***

matching_in_cleaned_data = list(filter(filterfunction, alldata_clean))
matching_ids = list(map(itemgetter('ProgramId'), matching_in_cleaned_data))
matching_names = list(map(itemgetter('Name'), matching_in_cleaned_data))
matching_ids, matching_names

# 'matching' does not exist in the data

# %%
# ***check keyword in filterfuntion before running***

Matching_in_cleaned_data = list(filter(filterfunction, alldata_clean))
Matching_ids = list(map(itemgetter('ProgramId'), Matching_in_cleaned_data))
Matching_names = list(map(itemgetter('Name'), Matching_in_cleaned_data))
Matching_ids, Matching_names
# Out:
# ([332, 4602],
#  ['MTC - Matching Grants for Communities',
#   'Oncor Electric Delivery - City and School Matching Grant Program'])

# %%
# ProgramIds for the key term "Matching":
# [332, 4602]


# Name of Program for key term "Matching":
#['MTC - Matching Grants for Communities',
#  'Oncor Electric Delivery - City and School Matching Grant Program']
